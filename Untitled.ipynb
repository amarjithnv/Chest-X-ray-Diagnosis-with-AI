# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from PIL import Image
from IPython.display import display
import ipywidgets as widgets

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Force CPU (optional)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# Dataset paths
data_dir = "/home/vinod/soft-apps/ai_diagnosis_env/dataset"
train_dir = os.path.join(data_dir, "train")
val_dir = os.path.join(data_dir, "val")
test_dir = os.path.join(data_dir, "test")

# Config
image_size = (224, 224)
batch_size = 32
seed = 123  # For reproducibility
AUTOTUNE = tf.data.AUTOTUNE

# Load Datasets
train_dataset = keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=image_size,
    batch_size=batch_size,
    shuffle=True,
    seed=seed
)

val_dataset = keras.preprocessing.image_dataset_from_directory(
    val_dir,
    image_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

test_dataset = keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=image_size,
    batch_size=batch_size,
    shuffle=False
)

# Get class names and number of classes
class_names = train_dataset.class_names
num_classes = len(class_names)
print("Class Names:", class_names)
print("Number of Classes:", num_classes)

# 🔄 Normalize and Prefetch
normalization_layer = layers.Rescaling(1./255)

train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
val_dataset = val_dataset.map(lambda x, y: (normalization_layer(x), y))
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# Extract all labels from the training dataset
all_labels = []
for _, labels in train_dataset.unbatch():
    all_labels.append(labels.numpy())
all_labels = np.array(all_labels)

# Compute class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(all_labels),
    y=all_labels
)

class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
print("Class Weights:", class_weights_dict)
# Out:
# Found 6326 files belonging to 4 classes.
# Found 38 files belonging to 4 classes.
# Found 771 files belonging to 4 classes.
# Class Names: ['COVID19', 'NORMAL', 'PNEUMONIA', 'TURBERCULOSIS']
# Number of Classes: 4
# Class Weights: {0: np.float64(3.4380434782608695), 1: np.float64(1.1793437733035048), 2: np.float64(0.4081290322580645), 3: np.float64(2.433076923076923)}

# %%
# Use DenseNet121 as a feature extractor
base_model = keras.applications.DenseNet121(
    weights='imagenet', include_top=False, input_shape=(224, 224, 3)
)
base_model.trainable = False

# Custom head
inputs = keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model = keras.Model(inputs, outputs)

# Compile model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,300,932 (27.85 MB)
#  Trainable params: 263,428 (1.00 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
# Train the model using class weights
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    class_weight=class_weights_dict
)
# Out:
# Epoch 1/50
# 2025-07-20 16:21:25.439006: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 19267968 bytes after encountering the first element of size 19267968 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 510s 3s/step - accuracy: 0.5485 - loss: 1.2017 - val_accuracy: 0.8158 - val_loss: 0.4162
# Epoch 2/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 0.8801 - loss: 0.3690 - val_accuracy: 0.8421 - val_loss: 0.3371
# Epoch 3/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 505s 3s/step - accuracy: 0.9044 - loss: 0.2599 - val_accuracy: 0.9211 - val_loss: 0.2935
# Epoch 4/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 489s 2s/step - accuracy: 0.9220 - loss: 0.2291 - val_accuracy: 0.9211 - val_loss: 0.2545
# Epoch 5/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 0.9266 - loss: 0.1914 - val_accuracy: 0.9211 - val_loss: 0.2126
# Epoch 6/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 487s 2s/step - accuracy: 0.9285 - loss: 0.1862 - val_accuracy: 0.9474 - val_loss: 0.2155
# Epoch 7/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 0.9441 - loss: 0.1497 - val_accuracy: 0.9474 - val_loss: 0.2050
# Epoch 8/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 485s 2s/step - accuracy: 0.9435 - loss: 0.1483 - val_accuracy: 0.9211 - val_loss: 0.1976
# Epoch 9/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 493s 2s/step - accuracy: 0.9495 - loss: 0.1341 - val_accuracy: 0.9474 - val_loss: 0.1673
# Epoch 10/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 0.9473 - loss: 0.1323 - val_accuracy: 0.9211 - val_loss: 0.1690
# Epoch 11/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 485s 2s/step - accuracy: 0.9555 - loss: 0.1131 - val_accuracy: 0.9211 - val_loss: 0.2216
# Epoch 12/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 504s 2s/step - accuracy: 0.9552 - loss: 0.1015 - val_accuracy: 0.9211 - val_loss: 0.1820
# Epoch 13/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 504s 2s/step - accuracy: 0.9594 - loss: 0.1036 - val_accuracy: 0.9211 - val_loss: 0.1815
# Epoch 14/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.9580 - loss: 0.0997 - val_accuracy: 0.9211 - val_loss: 0.1782
# Epoch 15/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 486s 2s/step - accuracy: 0.9626 - loss: 0.0897 - val_accuracy: 0.9211 - val_loss: 0.1523
# Epoch 16/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 506s 2s/step - accuracy: 0.9641 - loss: 0.0833 - val_accuracy: 0.9211 - val_loss: 0.1443
# Epoch 17/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.9636 - loss: 0.0853 - val_accuracy: 0.9211 - val_loss: 0.1629
# Epoch 18/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 500s 3s/step - accuracy: 0.9657 - loss: 0.0792 - val_accuracy: 0.9211 - val_loss: 0.2182
# Epoch 19/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 489s 2s/step - accuracy: 0.9665 - loss: 0.0750 - val_accuracy: 0.9211 - val_loss: 0.1785
# Epoch 20/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 487s 2s/step - accuracy: 0.9670 - loss: 0.0738 - val_accuracy: 0.9211 - val_loss: 0.2523
# Epoch 21/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 514s 3s/step - accuracy: 0.9693 - loss: 0.0681 - val_accuracy: 0.9211 - val_loss: 0.1918
# Epoch 22/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 525s 3s/step - accuracy: 0.9749 - loss: 0.0596 - val_accuracy: 0.9211 - val_loss: 0.1389
# Epoch 23/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 521s 3s/step - accuracy: 0.9720 - loss: 0.0617 - val_accuracy: 0.9211 - val_loss: 0.1565
# Epoch 24/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 502s 3s/step - accuracy: 0.9720 - loss: 0.0587 - val_accuracy: 0.9211 - val_loss: 0.1813
# Epoch 25/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 486s 2s/step - accuracy: 0.9760 - loss: 0.0592 - val_accuracy: 0.9211 - val_loss: 0.1713
# Epoch 26/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 484s 2s/step - accuracy: 0.9740 - loss: 0.0557 - val_accuracy: 0.9211 - val_loss: 0.1852
# Epoch 27/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 505s 2s/step - accuracy: 0.9764 - loss: 0.0500 - val_accuracy: 0.9211 - val_loss: 0.2079
# Epoch 28/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 487s 2s/step - accuracy: 0.9758 - loss: 0.0500 - val_accuracy: 0.9211 - val_loss: 0.2047
# Epoch 29/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 0.9786 - loss: 0.0495 - val_accuracy: 0.9211 - val_loss: 0.1905
# Epoch 30/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 506s 3s/step - accuracy: 0.9797 - loss: 0.0440 - val_accuracy: 0.9211 - val_loss: 0.1859
# Epoch 31/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.9832 - loss: 0.0396 - val_accuracy: 0.9211 - val_loss: 0.1839
# Epoch 32/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 0.9802 - loss: 0.0394 - val_accuracy: 0.9211 - val_loss: 0.1635
# Epoch 33/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 523s 3s/step - accuracy: 0.9787 - loss: 0.0429 - val_accuracy: 0.8947 - val_loss: 0.2067
# Epoch 34/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 529s 3s/step - accuracy: 0.9850 - loss: 0.0373 - val_accuracy: 0.9211 - val_loss: 0.1639
# Epoch 35/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 516s 3s/step - accuracy: 0.9809 - loss: 0.0360 - val_accuracy: 0.9211 - val_loss: 0.1930
# Epoch 36/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 486s 2s/step - accuracy: 0.9796 - loss: 0.0387 - val_accuracy: 0.8947 - val_loss: 0.2375
# Epoch 37/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 0.9805 - loss: 0.0358 - val_accuracy: 0.8684 - val_loss: 0.2735
# Epoch 38/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.9877 - loss: 0.0324 - val_accuracy: 0.8947 - val_loss: 0.2366
# Epoch 39/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 501s 2s/step - accuracy: 0.9859 - loss: 0.0311 - val_accuracy: 0.9211 - val_loss: 0.1580
# Epoch 40/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 512s 3s/step - accuracy: 0.9825 - loss: 0.0323 - val_accuracy: 0.9211 - val_loss: 0.1361
# Epoch 41/50
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 507s 3s/step - accuracy: 0.9850 - loss: 0.0299 - val_accuracy: 0.8684 - val_loss: 0.2424
# Epoch 42/50
#  58/198 ━━━━━━━━━━━━━━━━━━━━ 7:04 3s/step - accuracy: 0.9868 - loss: 0.0295

# %%
# Accuracy & Loss Graphs
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.7738 - loss: 0.6831
# Test Accuracy: 0.8301

# %%
y_true, y_pred = [], []

for images, labels in test_dataset:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#                precision    recall  f1-score   support
#
#       COVID19       0.96      0.90      0.93       106
#        NORMAL       0.98      0.50      0.66       234
#     PNEUMONIA       0.76      0.99      0.86       390
# TURBERCULOSIS       0.93      0.98      0.95        41
#
#      accuracy                           0.83       771
#     macro avg       0.91      0.84      0.85       771
#  weighted avg       0.86      0.83      0.82       771
# 2025-07-19 19:11:30.537847: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
model.save("chest_disease_model.keras")

# %%
from tensorflow.keras.preprocessing import image

def predict_custom_image(img_path, class_names):
    img = image.load_img(img_path, target_size=(224,224))
    plt.imshow(img)
    plt.axis('off')
    plt.title("Input X-ray")
    plt.show()
    
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    
    preds = model.predict(img_array)
    predicted_class = np.argmax(preds, axis=1)[0]
    confidence = np.max(preds)
    
    print(f"Prediction: {class_names[predicted_class]} ({confidence*100:.2f}% confidence)")

# File Upload Widget
uploader = widgets.FileUpload(accept='image/*', multiple=False)
display(uploader)

def on_upload_change(change):
    for filename in uploader.value:
        content = uploader.value[filename]['content']
        with open(filename, 'wb') as f:
            f.write(content)
        predict_custom_image(filename, class_names)
        os.remove(filename)

uploader.observe(on_upload_change, names='value')
# Out:
# FileUpload(value=(), accept='image/*', description='Upload')

# %%
# Example: direct path usage
img_path = "/home/vinod/soft-apps/ai_diagnosis_env/dataset/train/COVID19/COVID19(57).jpg"
predict_custom_image(img_path, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Prediction: COVID19 (99.94% confidence)
